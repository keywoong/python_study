# %% [markdown]
# ##1. 함수란?
# 함수는 하나의 특정 작업을 수행하는 코드들의 집합이다. <br>
# 함수는 필요한 매개값(매개변수)를 입력받고, 작업한 후, 결과값을 반환한다.
# - 반복적인 수행을 1회만 작성 후 호출
# - 코드를 논리적인 단위로 분리
# - 캡슐화 : 인터페이스만 알면 타인의 코드 사용
#
# <hr>

# %% [markdown]
# ## 2. 파이썬 함수 종류
# ### 2.1 기본함수
# - Built in 함수라고도 불림.
# - 파이썬 인터프리터 내에서 기본으로 내장된 함수이다.
# - `input()`, `print()`, `len()`, `del()`, `type()` 등이 있다.

# %% [markdown]
# ### 2.2 패키지 내장 함수
# - 특정 패키지나 모듈에 포함된 함수를 말한다.
# - math 모듈에 포함된 함수

# %% [markdown]
# ### 2.3 사용자 정의 함수
# - 사용자가 필요에 따라 특정 기능의 함수를 직접 작성

# %% [markdown]
# 예를 들어, <br>
# f(x) = 2x + 7, g(x) = x^2이고, x = 2일때, f(x) + g(x) + f(g(x)) + g(f(x))의 값은?<br>
# f(2) = 11, g(2) = 4, f(g(2)) = 15, g(f(x)) = 121 해서 151이다. <br>
# 이 공식을 파이썬으로 작성하면?

# %%
def f(x):
  return 2*x + 7
def g(x):
  return x**2
x = 2
print(f(x) + g(x) + f(g(x)) + g(f(x)))
# Out:
# 151

# %%
# 예제1 절댓값 계산하는 함수
# 매개변수가 1개이고, 반환 값을 adp wjwkd

def my_abs(value):
  if value <0:
    result = value * (-1)
  else:
    result = value
  return result

a = my_abs(-5)
print(a)
# Out:
# 5

# %%
# 예제2 문자열을 숫자만큼 반복 출력하는 함수
# 매개변수가 2개이고 반환값이 없는 함수

def print_string(text,count):
  for i in range(count):
    print(text)

print_string("파이썬 수업입니다", 3)
# Out:
# 파이썬 수업입니다
# 파이썬 수업입니다
# 파이썬 수업입니다

# %% [markdown]
# <hr>

# %% [markdown]
# ## 3. 매개변수
# <b>Parameter vs Argument</b>
# - parameter : 함수의 입력값 인터페이스
# - argument : 실제 parameter에 대입된 값

# %%
def f(x): #x : Parameter
  return 2*x + 7
print(f(2)) # 2 : Argument
# Out:
# 11

# %% [markdown]
# Parameter(input)와 Return Value(output)의 유무에 따라 함수의 형태가 다르다.<br>
# - parameter X & return value X : 함수 내의 수행문만 수행 <br>
# - parameter X & return value O : 인자 없이 수행문 수행 후, 결과값 반환<br>
# - parameter O & return value X : 인자를 사용, 수행문만 수행 <br>
# - parameter O & return value O : 인자를 사용하여 수행문 수행 후 결과값 반환 <br>

# %%
def a():# parameter X, return value X
  print (5*7)
def b():
  return 5*7
def c(x,y):
  print(x*y)
def d(x,y):
  return x*y
print('a():',a())
print('b():',b())
print('c(5,7):',c(5,7))
print('d(5,7):',d(5,7))
# Out:
# 35
# a(): None
# b(): 35
# 35
# c(5,7): None
# d(5,7): 35

# %% [markdown]
# 여기서 `a()`와 `c(5,7)`은 35가 출력되고 None이 출력되는 것을 알 수 있다.<br>
# (1) a()함수 혹은 c(5,7)함수를 실행<br>
# (2) a,c함수의 print(5*7)구문을 실행 → 35<br>
# (3) Return 값이 없으므로 None 출력 → None<br>

# %% [markdown]
# ### 3.1 기본 매개변수
# 함수를 정의할 때, 매개변수의 기본값을 설정할 수 있다.<br>
# 기본값이 설정된 매개변수를 기본 매개변수라고 하며, 함수를 호출할 때 함수 내 매개변수를 입력하지 않으면 기본값이 자동설정된다.

# %%
# 예제3 예제2에서 반복횟수 기본값(default)값 지정

def print_string(text,count=1):
  for i in range(count):
    print(text)

print_string("파이썬 수업입니다")
# Out:
# 파이썬 수업입니다

# %% [markdown]
# ### 3.2 가변 매개변수
# - 함수를 정의할 때 매개변수를 크기가 정해지지 않은 순서열 데이터로 정의 가능 ( &#42; 는 튜플, &#42; &#42;는 딕셔너리, &#42;는 <b>asterisk</b>라고 한다.)
# - 함수를 호출할 때 매개변수 값을 원하는 만큼 입력 가능
# - 가변 매개변수는 함수 당 하나만 정의 가능
# - 일반 매개변수를 항상 먼저 정의해야 함.
# - 가변 매개변수는 오직 한개만 맨 마지막 parameter 위치에 사용가능하다.

# %%
# 예제4 예제2에서 출력 문자열을 가변 매개변수로 지정

def print_string(count,*text):
  for i in range(count):
    print(text)

print_string(3, "파이썬", "수업","입니다.")
# Out:
# ('파이썬', '수업', '입니다.')
# ('파이썬', '수업', '입니다.')
# ('파이썬', '수업', '입니다.')

# %% [markdown]
# 가변인자는 일반적으로 &#42;args를 변수명으로 사용하긴 한다. (위의 예시는 열외)<br>
# 기존 parameter 이후에 나오는 값을 tuple로 저장한다.

# %%
def asterisk_test(a,b,*args):
  return a*b+sum(args)
print(asterisk_test(1,2,3,4,5))
# Out:
# 14

# %%
def asterisk_test1(a,b,*args):
  return args
print(asterisk_test1(1,2,3,4,5))
print(type(asterisk_test1(1,2,3,4,5)))
# Out:
# (3, 4, 5)
# <class 'tuple'>

# %%
def asterisk_test2(a,b,*args):
  return args[0]
print(asterisk_test2(1,2,3,4,5))
print(type(asterisk_test2(1,2,3,4,5)))
# Out:
# 3
# <class 'int'>

# %%
def asterisk_test3(*args):
  x,y,z = args #unpacking
  return x,y,z
print(asterisk_test3(1,2,3))
# Out:
# (1, 2, 3)

# %%
def f(*args):
  x,y,z = args
  return args
print(f(1,2,3,4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-903816bca953> in <module>()
#       2   x,y,z = args
#       3   return args
# ----> 4 print(f(1,2,3,4))
#
# <ipython-input-21-903816bca953> in f(*args)
#       1 def f(*args):
# ----> 2   x,y,z = args
#       3   return args
#       4 print(f(1,2,3,4))
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# #### 키워드 가변인자 (Keyword variable-length)
# - parameter 이름을 따로 지정하지 않고 입력하는 방법
# - Asterisk(&#42;) 2개를 사용하여 함수의 parameter를 표시한다.
# - 입력된 값은 dict type로 사용할 수 있다.
# - 키워드 가변인자는 오직 한 개만 기존 가변인자 다음에 사용한다.

# %%
# 예제5 가변 매개변수를 딕셔너리로 저장한 예시

def personal_info(**person):
  for key in person.keys():
    print("{}:{}".format(key, person[key]))

personal_info(name = "홍길동", age = 30, address = "인천광역시 미추홀구 용현동")
# Out:
# name:홍길동
# age:30
# address:인천광역시 미추홀구 용현동

# %%
def kwargs_test1(**kwargs):
  print(kwargs)
def kwargs_test2(**kwargs):
  print(kwargs)
  print('First value is {first}'.format(**kwargs))
  print('Second value is {second}'.format(**kwargs))
  print('Third value is {third}'.format(**kwargs))

# %%
kwargs_test1(first = 3, second = 4, third=  5)
# Out:
# {'first': 3, 'second': 4, 'third': 5}

# %%
kwargs_test2(first = 3, second = 4, third=  5)
# Out:
# {'first': 3, 'second': 4, 'third': 5}
# First value is 3
# Second value is 4
# Third value is 5

# %% [markdown]
# 모든 arguments를 사용한 예

# %%
def all_arguments(one, two, *args, **kwargs):
  print(one+two+sum(args))
  print(kwargs)
all_arguments(3,4,5,6,7,8,9, first = 3, second = 4, thrid = 5)
# Out:
# 42
# {'first': 3, 'second': 4, 'thrid': 5}

# %% [markdown]
# ## 3.3 키워드 매개변수
# 함수를 호출할 때, 매개변수의 이름을 직접 지정해서 값을 입력하는 방식<br>
# 1) 기본 매개변수와 가변 매개변수를 같이 사용하고 싶을 때
# - 기본 매개변수를 가변 매개변수보다 나중에 정의해야 한다.
# - 함수 호출 시, 기본 매개변수의 값을 입력할 때 키워드 매개변수로 입력

# %%
# 1-1. 기본 매개변수를 먼저 선언한 경우
def print_string(count = 3, *text):
  for i in range(count):
    for t in text:
      print(t)
    print()

print_string("파이썬", "프로그래밍", "수업입니다.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5439497bbe26> in <module>()
#       6     print()
#       7
# ----> 8 print_string("파이썬", "프로그래밍", "수업입니다.")
#
# <ipython-input-6-5439497bbe26> in print_string(count, *text)
#       1 # 1-1. 기본 매개변수를 먼저 선언한 경우
#       2 def print_string(count = 3, *text):
# ----> 3   for i in range(count):
#       4     for t in text:
#       5       print(t)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# 기본매개변수와 가변매개변수 중 기본 매개변수를 먼저 정의한 경우에는 함수를 불러올 때, 기본 매개변수의 값을 입력할 때 키워드 매개변수로 입력해야한다.

# %%
# 1-2. 가변매개변수를 먼저 선언한 경우
def print_string(*text,count = 3):
  for i in range(count):
    for t in text:
      print(t)
    print()

print_string("파이썬", "프로그래밍", "수업입니다.")
# Out:
# 파이썬
# 프로그래밍
# 수업입니다.
#
# 파이썬
# 프로그래밍
# 수업입니다.
#
# 파이썬
# 프로그래밍
# 수업입니다.

# %%
# 1-3. 함수 호출 시, 키워드 매개변수를 사용해서 기본 매개변수의 값 입력

def print_string(*text, count = 1):
  for i in range(count):
    for t in text:
      print(t)
    print()

print(">>count 키워드 사용")
print_string("파이썬","프로그래밍","수업입니다",count=1)
print(">>count 키워드 사용x")
print_string("파이썬","프로그래밍","수업입니다",2)
# Out:
# >>count 키워드 사용
# 파이썬
# 프로그래밍
# 수업입니다
#
# >>count 키워드 사용x
# 파이썬
# 프로그래밍
# 수업입니다
# 2

# %%
# 1-4. 기본 매개변수 중 필요한 값만 입력하거나 순서 상관없이 입력하기
def sum(a,b = 10, c = 100):
  return a+2*b+3*c

print(sum(1,20,100)) #(1,20,100)
print(sum(1,c = 20,b = 100)) #(1,100,20)
print(sum(1,20)) #(1,20,100)
print(sum(1,c = 100)) #(1,10,100)
# Out:
# 341
# 261
# 341
# 321

# %%
# 1-5. 매개변수 없이 반환값만 있는 함수
def get_init():
  while 1:
    print("정수를 입력하세요")
    n = input()
    print("입력받은 숫자" +n)
    if n.isdecimal():
        break
  return int(n)

a = get_init()
print("변수 a = {}".format(a))
# Out:
# 정수를 입력하세요
# 3.2
# 입력받은 숫자3.2
# 정수를 입력하세요
# 3
# 입력받은 숫자3
# 변수 a = 3

# %%
# 1-6. 문구 2회 이하만 출력하기
def print_string(count, *text):
  for i in range(1,count+1):
    for t in text:
      print(t)
    print()
    if i ==2:
      return

print_string(1, "파이썬")
print_string(4, "프로그래밍")
# Out:
# 파이썬
#
# 프로그래밍
#
# 프로그래밍

# %% [markdown]
# i가 2가 되면 return을 하도록 한다. 이때 return에 빈 값을 넣어서 반환한다. >> return을 프로그램을 종료시키는 용도로 사용

# %% [markdown]
# ## 3.4 함수의 필요성
# - 프로그램이 크고 복잡한 경우, 이를 함수로 만들어 부분으로 분해할 수 있다.
# - 한번 작성된 함수는 여러번 호출해서 사용할 수 있다.
# - 한번 작성된 함수를 다른 프로그램에서 사용할 수 있다.
# - 코드의 안전성이 좋아지고 에러 수정하기 쉬워짐.
#
# <hr>

# %% [markdown]
# # 4. 함수 응용
# (둘 이상의 값 반환, 팩토리알, 피보나치)

# %% [markdown]
# ## 4.1 함수에서 둘 이상의 값 반환하기
# 2개 이상의 값을 콤마로 구분해서 반환, 이는 튜플로 묶어서 반환하는 것과 동일

# %%
# 둘 이상의 값 반환하기
def add_sub(a,b):
  return a+b, a-b

x, y = add_sub(10,20)
print(x)
print(y)
# Out:
# 30
# -10

# %%
# 둘 이상의 값 반환하기 (리스트)
def return_list(list_):
  return [2*i for i in list_]

list1 = [1,3,5,7,9]
list2 = return_list(list1)
print(list2)
# Out:
# [2, 6, 10, 14, 18]

# %% [markdown]
# ### 4.2 팩토리알

# %%
# 반복문으로 구하기

def factorial1(n):
  result = 1
  for i in range(1,n+1):
    result *=i
  return result

print("4의 팩토리알은 {}".format(factorial1(4)))
print("5의 팩토리알은 {}".format(factorial1(5)))
# Out:
# 4의 팩토리알은 24
# 5의 팩토리알은 120

# %%
# 재귀함수로 구하기

def factorial2(n):
  if n == 0:
    return 1
  else:
    return n*factorial2(n-1)

print("4의 팩토리알은 {}".format(factorial2(4)))
print("5의 팩토리알은 {}".format(factorial2(5)))
# Out:
# 4의 팩토리알은 24
# 5의 팩토리알은 120

# %% [markdown]
# `재귀함수`는 함수 안에서 함수 자기 자신을 호출하는 함수로, 언제까지 재귀함수 호출을 할 것인지 **종료조건**을 만들어줘야 한다.

# %%
def factorial(n):
  if n==0:
    return 1
  else:
    return n*factorial(n-1)
factorial(8)
# Out:
# 40320

# %% [markdown]
# ### 4.3 피보나치 수열
# 앞의 두 수를 더하면 다음 수가 나오는 수열 <br>
# 1, 1, 2, 3, 5, 8, 13,...

# %%
def fibo(n):
  if n==1:
    return 1
  elif n==2:
    return 1
  else:
    return fibo(n-1) + fibo(n-2)

for i in range(1,10):
  print(fibo(i))
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21
# 34
